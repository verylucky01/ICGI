# %%
import openai
from openai import OpenAI
from datetime import datetime

# %%
def get_completions(system_prompt, user_prompt, max_tokens_=32):
    client = OpenAI(
        api_key="sk-xauJxj7A2otle4oRDe94Dd5f35214e04A6F240C1089c8063",
        base_url="https://api.bltcy.ai/v1",
        max_retries=3,
        timeout=60,
    )
    chat_completion = client.chat.completions.create(
        model="gpt-4o-mini-2024-07-18",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt},
        ],
        n=1,
        temperature=0,
        seed=42,
        max_tokens=max_tokens_,
        logprobs=False,
        presence_penalty=0,
        frequency_penalty=0,
    )
    response = chat_completion.choices[0].message.content.strip()

    return chat_completion, response

# %%
# 使用了 Python 的 f-string（格式化字符串）来打印 openai 库的版本号：
print(f"OpenAI Python API Library Version: {openai.__version__}")
# Out:
# OpenAI Python API Library Version: 1.58.1

# %%
# 当系统提示没有特定要求时，可以使用以下这个系统提示。
system_ = "You are a helpful assistant."

# 您的任务是推断 LiBai 基因与肺腺癌之间是否存在因果关系。
prompt = "How sure are you about the causal relationship between the LiBai gene and lung adenocarcinoma?"
completion_object, result = get_completions(system_, prompt, max_tokens_=256)
print(result)
# Out:
# As of my last knowledge update in October 2023, there is ongoing research into the role of various genes and pathways in lung adenocarcinoma, including the LiBai gene. However, the exact causal relationship between the LiBai gene and lung adenocarcinoma is not definitively established in the scientific literature.
#
# Causality in cancer genetics is complex and typically requires extensive studies, including functional studies, epidemiological studies, and often validation in clinical settings to confirm that a particular gene directly contributes to the development or progression of a specific cancer.
#
# If you are looking for the most current and specific information regarding the LiBai gene and its association with lung adenocarcinoma, I recommend checking recent scientific publications or databases that focus on cancer genetics, as new discoveries are made frequently.

# %%
completion_object
# Out:
# ChatCompletion(id='chatcmpl-AiNNz9gcmWZdygywZdm2ezCriSVh0', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='As of my last knowledge update in October 2023, there is ongoing research into the role of various genes and pathways in lung adenocarcinoma, including the LiBai gene. However, the exact causal relationship between the LiBai gene and lung adenocarcinoma is not definitively established in the scientific literature.\n\nCausality in cancer genetics is complex and typically requires extensive studies, including functional studies, epidemiological studies, and often validation in clinical settings to confirm that a particular gene directly contributes to the development or progression of a specific cancer.\n\nIf you are looking for the most current and specific information regarding the LiBai gene and its association with lung adenocarcinoma, I recommend checking recent scientific publications or databases that focus on cancer genetics, as new discoveries are made frequently.', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None))], created=1735139691, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier=None, system_fingerprint='fp_0aa8d3e20b', usage=CompletionUsage(completion_tokens=161, prompt_tokens=38, total_tokens=199, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
